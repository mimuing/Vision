# %%
from google.colab import drive
drive.mount('/content/drive')


import os

from PIL import Image
from google.colab import drive
os.chdir("/content/drive/My Drive/FST_CNN/FST_4차/Augmentation_cnn") #학습Data 주소

import numpy as np
import matplotlib.pyplot as plt

# Importing all necessary libraries
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
#from keras.layers.normalization import BatchNormalization
from keras import backend as K

img_width, img_height = 512, 512

train_data_dir = '/content/drive/MyDrive/FST_CNN/FST_4차/Augmentation_cnn/Train' #Train data 주소
validation_data_dir = '/content/drive/MyDrive/FST_CNN/FST_4차/Augmentation_cnn/Validation' #Validation data 주소
nb_train_samples =4914            #Train data 개수
nb_validation_samples = 1062    #Validation data 개수
epochs = 100
batch_size = 10

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import skimage.io as io
from skimage.transform import rotate, AffineTransform, warp
from skimage.util import random_noise
from skimage.filters import gaussian
import matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from torchsummary import summary
import pandas as pd
import numpy as np
from skimage.io import imread, imsave
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from skimage.transform import rotate
from skimage.util import random_noise
from skimage.filters import gaussian
from scipy import ndimage
import cv2

# %% [markdown]
# Augmentation Validation data

# %%
#BS
import glob
from PIL import Image

myPath='/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS/'
fileCounter = len(glob.glob1(myPath,"*.bmp"))
fileCounter=fileCounter+1+1200
os.chdir("/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS") #학습Data 주소

for i in range(1201,fileCounter):
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS/'+"%04d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  imgae_path='/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS/'+"%04d.bmp" %i
  img=imread(imgae_path)
  transform = AffineTransform(translation=(100,25))
  wrapShift = warp(image,transform,mode='wrap')
  plt.imshow(wrapShift)
  plt.title('Wrap Shift')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  j=4*i-3
  plt.savefig(fname='%d.jpg'%j, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS/%d.jpg'%j)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS/%d.jpg'%j)

  #flip image left-to-right
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS/'+"%04d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  flipLR = np.fliplr(image)
  plt.imshow(flipLR)
  plt.title('Left to Right Flipped')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  k=4*i-2
  plt.savefig(fname='%d.jpg'%k, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS/%d.jpg'%k)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS/%d.jpg'%k)


  #flip image up-to-down
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS/'+"%04d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  flipUD = np.flipud(image)
  plt.imshow(flipUD)
  plt.title('Up Down Flipped')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  z=4*i-1
  plt.savefig(fname='%d.jpg'%z, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS/%d.jpg'%z)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS/%d.jpg'%z)


  #standard deviation for noise to be added in the image
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS/'+"%04d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  sigma=0.155
  #add random noise to the image
  noisyRandom = random_noise(image,var=sigma**2)
  plt.imshow(noisyRandom)
  plt.title('Random Noise')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  q=4*i
  plt.savefig(fname='%d.jpg'%q, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS/%d.jpg'%q)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS/%d.jpg'%q)

# %%
#BS2
import glob
from PIL import Image

myPath='/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS2/'
fileCounter = len(glob.glob1(myPath,"*.bmp"))
fileCounter=fileCounter+1+37
os.chdir("/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS2") #학습Data 주소

for i in range(38,fileCounter):
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS2/'+"%02d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  imgae_path='/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS2/'+"%02d.bmp" %i
  img=imread(imgae_path)
  transform = AffineTransform(translation=(100,25))
  wrapShift = warp(image,transform,mode='wrap')
  plt.imshow(wrapShift)
  plt.title('Wrap Shift')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  j=4*i-3
  plt.savefig(fname='%d.jpg'%j, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS2/%d.jpg'%j)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS2/%d.jpg'%j)

  #flip image left-to-right
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS2/'+"%02d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  flipLR = np.fliplr(image)
  plt.imshow(flipLR)
  plt.title('Left to Right Flipped')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  k=4*i-2
  plt.savefig(fname='%d.jpg'%k, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS2/%d.jpg'%k)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS2/%d.jpg'%k)


  #flip image up-to-down
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS2/'+"%02d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  flipUD = np.flipud(image)
  plt.imshow(flipUD)
  plt.title('Up Down Flipped')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  z=4*i-1
  plt.savefig(fname='%d.jpg'%z, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS2/%d.jpg'%z)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS2/%d.jpg'%z)


  #standard deviation for noise to be added in the image
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/BS2/'+"%02d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  sigma=0.155
  #add random noise to the image
  noisyRandom = random_noise(image,var=sigma**2)
  plt.imshow(noisyRandom)
  plt.title('Random Noise')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  q=4*i
  plt.savefig(fname='%d.jpg'%q, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS2/%d.jpg'%q)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/BS2/%d.jpg'%q)

# %%
#FS
import glob
from PIL import Image

myPath='/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS/'
fileCounter = len(glob.glob1(myPath,"*.bmp"))
fileCounter=fileCounter+1+600
os.chdir("/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS") #학습Data 주소

for i in range(601,fileCounter):
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS/'+"%03d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  imgae_path='/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS/'+"%03d.bmp" %i
  img=imread(imgae_path)
  transform = AffineTransform(translation=(100,25))
  wrapShift = warp(image,transform,mode='wrap')
  plt.imshow(wrapShift)
  plt.title('Wrap Shift')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  j=4*i-3
  plt.savefig(fname='%d.jpg'%j, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS/%d.jpg'%j)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS/%d.jpg'%j)

  #flip image left-to-right
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS/'+"%03d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  flipLR = np.fliplr(image)
  plt.imshow(flipLR)
  plt.title('Left to Right Flipped')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  k=4*i-2
  plt.savefig(fname='%d.jpg'%k, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS/%d.jpg'%k)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS/%d.jpg'%k)


  #flip image up-to-down
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS/'+"%03d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  flipUD = np.flipud(image)
  plt.imshow(flipUD)
  plt.title('Up Down Flipped')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  z=4*i-1
  plt.savefig(fname='%d.jpg'%z, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS/%d.jpg'%z)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS/%d.jpg'%z)


  #standard deviation for noise to be added in the image
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS/'+"%03d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  sigma=0.155
  #add random noise to the image
  noisyRandom = random_noise(image,var=sigma**2)
  plt.imshow(noisyRandom)
  plt.title('Random Noise')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  q=4*i
  plt.savefig(fname='%d.jpg'%q, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS/%d.jpg'%q)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS/%d.jpg'%q)

# %%
#FS2
import glob
from PIL import Image

myPath='/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS2/'
fileCounter = len(glob.glob1(myPath,"*.bmp"))
fileCounter=fileCounter+1+36
os.chdir("/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS2") #학습Data 주소

for i in range(37,fileCounter):
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS2/'+"%02d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  imgae_path='/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS2/'+"%02d.bmp" %i
  img=imread(imgae_path)
  transform = AffineTransform(translation=(100,25))
  wrapShift = warp(image,transform,mode='wrap')
  plt.imshow(wrapShift)
  plt.title('Wrap Shift')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  j=4*i-3
  plt.savefig(fname='%d.jpg'%j, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS2/%d.jpg'%j)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS2/%d.jpg'%j)

  #flip image left-to-right
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS2/'+"%02d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  flipLR = np.fliplr(image)
  plt.imshow(flipLR)
  plt.title('Left to Right Flipped')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  k=4*i-2
  plt.savefig(fname='%d.jpg'%k, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS2/%d.jpg'%k)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS2/%d.jpg'%k)


  #flip image up-to-down
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS2/'+"%02d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  flipUD = np.flipud(image)
  plt.imshow(flipUD)
  plt.title('Up Down Flipped')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  z=4*i-1
  plt.savefig(fname='%d.jpg'%z, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS2/%d.jpg'%z)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS2/%d.jpg'%z)


  #standard deviation for noise to be added in the image
  image = io.imread('/content/drive/My Drive/FST_CNN/FST_4차/Validation/FS2/'+"%02d.bmp" %i)
#  image = cv2.imread("/content/drive/My Drive/FST_CNN/FST_4차/Train/BS2/"+"%02d.bmp" %i, cv2.IMREAD_UNCHANGED)
  sigma=0.155
  #add random noise to the image
  noisyRandom = random_noise(image,var=sigma**2)
  plt.imshow(noisyRandom)
  plt.title('Random Noise')
  plt.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, hspace = 0, wspace = 0)
  plt.axis('off')
  plt.title('')
  plt.xticks([]), plt.yticks([])
  plt.tight_layout()
  q=4*i
  plt.savefig(fname='%d.jpg'%q, bbox_inches='tight', pad_inches=0)
  image = Image.open('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS2/%d.jpg'%q)
  resize_image = image.resize((512,512))
  resize_image.save('/content/drive/My Drive/FST_CNN/FST_4차/Augmentation/Validation/FS2/%d.jpg'%q)

# %% [markdown]
# CNN 학습

# %%
model = Sequential()
model.add(Conv2D(32, (2, 2), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(32, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (2, 2)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
#model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('softmax'))

# %%
#rmsprop
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

from keras.models import load_model

#model.load_weights('model_saved.h5') #저장된 weight파일 실행
#model.load_weights('multi_model_saved.h5') #weight파일 저장

history=model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

model.save_weights('Multi_class_CNN_100epoch_model_saved.h5') #weight파일 저장
# Out:
# Found 4914 images belonging to 4 classes.
# Found 1062 images belonging to 4 classes.
# Epoch 1/100
# 491/491 [==============================] - 4166s 8s/step - loss: 0.9657 - accuracy: 0.7436 - val_loss: 1.1452 - val_accuracy: 0.7500
# Epoch 2/100
# 491/491 [==============================] - 313s 638ms/step - loss: 0.9386 - accuracy: 0.7428 - val_loss: 1.2019 - val_accuracy: 0.7500
# Epoch 3/100
# 491/491 [==============================] - 309s 629ms/step - loss: 0.9307 - accuracy: 0.7457 - val_loss: 1.1299 - val_accuracy: 0.7500
# Epoch 4/100
# 491/491 [==============================] - 310s 630ms/step - loss: 0.5435 - accuracy: 0.8994 - val_loss: 0.4227 - val_accuracy: 0.9368
# Epoch 5/100
# 491/491 [==============================] - 312s 636ms/step - loss: 0.2457 - accuracy: 0.9680 - val_loss: 0.2747 - val_accuracy: 0.9392
# Epoch 6/100
# 491/491 [==============================] - 314s 639ms/step - loss: 0.2401 - accuracy: 0.9682 - val_loss: 0.5944 - val_accuracy: 0.9179
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1.1])
plt.xlim([0, 100])
plt.legend(loc='lower right')
